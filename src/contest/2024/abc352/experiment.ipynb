# %%
import random

n=2*10**5
k=10**5

xs=list(range(1, n+1))
random.shuffle(xs)

print(n, k)
print(*xs)
# Out:
# 200000 100000
# ...

# %%
n=2*10**5
xs=list(range(1, n+1))
random.shuffle(xs)

m = xs[0]
cnt = 0

for x in xs:
    if x < m:
        m = x
        cnt+=1

print(cnt)
# Out:
# 10
